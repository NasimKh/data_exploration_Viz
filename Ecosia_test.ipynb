# %% [markdown]
# Code written by Nasim Khadem

# %% [markdown]
# ### Question
#
# 1. It uses the sample dataset https://raw.githubusercontent.com/localytics/data-viz-challenge/master/data.json
#
# 2. Loads this data (make sure that you don't manually download the data but do it programmatically), processes it and outputs the following CSV file to s3:
#
# 3. Create an output file  total_events with these parameters:
#
# a. it has the following columns:  age, device, date, count, sum.
#
# b. group on gender, age, device and date of client_time
#
# c. the date column has the format of YYYY-MM-DD
#
# d. count column is the count of entries
#
# e. sum column is the summing the value of the 'amount' key
#
# f. only calculates entries for female ( "gender": "F" ) and Californian ("state": "CA") users.
#
# You can use Python libraries if you wish. For completing the assignment please send me the program that you wrote, and the location of the CSV output file.

# %% [markdown]
# ### Modules
# Importing Python Modules

# %%
import pandas as pd 
import os
import numpy as np
import json,urllib.request
import datetime
import boto3

# %% [markdown]
# ### Load
# Reading the json file programatically from the given URL.

# %%
url="https://raw.githubusercontent.com/localytics/data-viz-challenge/master/data.json"
data = urllib.request.urlopen(url).read()
output = json.loads(data)

# %% [markdown]
# Write the json to file for easy acess.

# %%
json_file_name=os.path.join(url.split ("/")[-1])
with open(json_file_name, mode='w') as outfile:
    json.dump(output, outfile)

# %% [markdown]
# Reading the json file into a dataframe

# %%
df = pd.read_json(json_file_name,orient='split')

# %% [markdown]
# Inspecting the dataframe to have a sense of the data.

# %%
df.head(5)
# Out:
#      age  amount     category         client_time   device    event_name  \
# 0  18-24     NaN       Sports 2014-03-01 00:00:04  android  View Project
# 1  18-24     NaN   Technology 2014-03-01 00:00:22      iOS  View Project
# 2    55+     NaN  Environment 2014-03-01 00:00:32      iOS  View Project
# 3  18-24     NaN   Technology 2014-03-01 00:00:38  android  View Project
# 4  25-34     NaN       Sports 2014-03-01 00:00:51      iOS  View Project
#
#   gender                                           location marital_status  \
# 0      M  {'latitude': 40.189788, 'city': 'Lyons', 'stat...        married
# 1      M  {'latitude': 33.844371, 'city': 'Alpharetta', ...         single
# 2      M  {'latitude': 42.446396, 'city': 'Westford', 's...         single
# 3      M  {'latitude': 44.624413, 'city': 'Saranac', 'st...         single
# 4      F  {'latitude': 36.747083, 'city': 'Lampe', 'stat...        married
#
#                          session_id
# 0  69f62d2ae87640f5a2dde2b2e9229fe6
# 1  4459d001feb8438eae5f4ec24abcd992
# 2  0db9ed700a184d48a9d04806696e3642
# 3  68195e2372bd4022b17220fc21de9138
# 4  9508a8385dc94773baba8aa7d1c2aa75

# %% [markdown]
# ### location
# The location is not in the correct format.

# %%
df=pd.concat([df.drop(['location'], axis=1), df['location'].apply(pd.Series)], axis=1)

# %%
df.head(5)
# Out:
#      age  amount     category         client_time   device    event_name  \
# 0  18-24     NaN       Sports 2014-03-01 00:00:04  android  View Project
# 1  18-24     NaN   Technology 2014-03-01 00:00:22      iOS  View Project
# 2    55+     NaN  Environment 2014-03-01 00:00:32      iOS  View Project
# 3  18-24     NaN   Technology 2014-03-01 00:00:38  android  View Project
# 4  25-34     NaN       Sports 2014-03-01 00:00:51      iOS  View Project
#
#   gender marital_status                        session_id        city  \
# 0      M        married  69f62d2ae87640f5a2dde2b2e9229fe6       Lyons
# 1      M         single  4459d001feb8438eae5f4ec24abcd992  Alpharetta
# 2      M         single  0db9ed700a184d48a9d04806696e3642    Westford
# 3      M         single  68195e2372bd4022b17220fc21de9138     Saranac
# 4      F        married  9508a8385dc94773baba8aa7d1c2aa75       Lampe
#
#     latitude   longitude state zip_code
# 0  40.189788 -105.355280    CO    80540
# 1  33.844371  -84.474050    GA    30009
# 2  42.446396  -71.459405    MA    01886
# 3  44.624413  -73.809266    NY    12981
# 4  36.747083  -93.458626    MO    65681

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50000 entries, 0 to 49999
# Data columns (total 14 columns):
# age               50000 non-null object
# amount            20658 non-null float64
# category          50000 non-null object
# client_time       50000 non-null datetime64[ns]
# device            50000 non-null object
# event_name        50000 non-null object
# gender            50000 non-null object
# marital_status    50000 non-null object
# session_id        50000 non-null object
# city              50000 non-null object
# latitude          50000 non-null float64
# longitude         50000 non-null float64
# state             50000 non-null object
# zip_code          50000 non-null object
# dtypes: datetime64[ns](1), float64(3), object(10)
# memory usage: 5.7+ MB

# %% [markdown]
# ### date format
# client date has to be changed to " the date column has the format of YYYY-MM-DD"

# %%
pd.to_datetime(df['client_time'], format='%Y%m%d', errors='coerce')
df['date'] = df['client_time'].dt.date

# %% [markdown]
# The amount has many nans , here I fill  NaNs with zeros.

# %%
df['amount'].fillna(0, inplace=True)

# %% [markdown]
# check to see if the date and Nans have been replaced correctly

# %%
df.tail()
# Out:
#          age  amount    category         client_time   device    event_name  \
# 49995  18-24    35.0      Sports 2014-03-31 23:48:40      iOS  Fund Project
# 49996  45-54     0.0  Technology 2014-03-31 23:49:29  android  View Project
# 49997  25-34     0.0     Fashion 2014-03-31 23:51:33      iOS  View Project
# 49998  35-44    37.0      Sports 2014-03-31 23:52:48      iOS  Fund Project
# 49999  18-24     0.0     Fashion 2014-03-31 23:58:45      iOS  View Project
#
#       gender marital_status                        session_id          city  \
# 49995      F        married  412b973788704c36a008a506cdbba033     West Linn
# 49996      F         single  4addd36a6f4347c59865fe04a92e8d57     Greenwich
# 49997      F         single  3181a138a0b94d1da9a3d29f7816fcc7         Irwin
# 49998      F        married  2df6b9a0c66b48a389330327517b9276  Martinsville
# 49999      M         single  fc24339bfda84ff29102981cbee78023   Lake Oswego
#
#         latitude   longitude state zip_code        date
# 49995  45.343615 -122.664926    OR    97068  2014-03-31
# 49996  41.079983  -73.654472    CT    06831  2014-03-31
# 49997  40.365020  -79.584060    PA    15642  2014-03-31
# 49998  39.477625  -86.466792    IN    46151  2014-03-31
# 49999  45.408374 -122.691388    OR    97034  2014-03-31

# %% [markdown]
# ### Filter by State and gender
# Filter out the data for "only calculates entries for female ( "gender": "F" ) and Californian ("state": "CA") users."

# %%
f_df=df[(df['state']=='CA') & (df['gender']=='F')]

# %%
f_df
# 1026       F        married  c0268ae7cc4648fb8539c4603bbfddbf
# 1034       F         single  946a6b7046964b8d90b8a8598bb658ed
# 1078       F        married  4e7beaf4ca094f75a0fd06004744607b
# 1093       F         single  4e3c3d2bae0f4a21ab862a41ce9b1889
# 1112       F         single  ad84994dfece406b822d3f940216bc50
# 1151       F        married  1727274af6b04a108e2ebf247713d28a
# 1163       F         single  04f408684c2049ea8708d8824ce8b6a0
# 1211       F         single  19854046097b4038b7c8ce345c0b6695
# 1256       F         single  621aa09b1b4642a1bd5ce2c668ba4667
# ...      ...            ...                               ...
# 48638      F         single  bb90263e0f024e5baba7d1c7bcf5ef85
# 48691      F         single  51a6f4039e914d76b33c67382d7e128a
# 48694      F        married  576f914229234193a11550f233c944c0
# 48750      F         single  578bc26b94474e7e863d01971f189d8a
# 48856      F        married  55416b7328a245efb0a804548c329c34
# 48920      F        married  91438ba2e682400ba9cdf23b9a0877d8
# 48991      F        married  e68f04ca7fbf488792373b458c193a31
# 49014      F         single  612952e0162f457ab1f3ea2f50a5243d
# 49019      F         single  2a58a4e085f2479490660ea3cdde40c3
# 49030      F         single  ccc589bd49dc4a0782dbdd41c5457704
# 49110      F        married  a8a744b9a609423d934188d7516ecfef
# 49151      F        married  7f2302bc9ddc4d0f83700fd4941f94c1
# 49169      F        married  ae6a8becd328400eadae41ce6c5b9b03
# 49184      F         single  d456a70b0a064074a425cbb8708718ef
# 49231      F        married  7954aa3359e74b74a58097c41376c4e7
# 49274      F        married  bb96450e4ea2463390a31f7e834dfac5
# 49301      F        married  a63dc075114e49068787445c2dd80351
# 49347      F        married  699c5893a5894b04be350b140ba51a78
# 49414      F        married  65113fc91e2243ddbe62a20843cda3f9
# 49416      F        married  9d846cba389c44ffb49b302f81cf3a7c
# 49474      F         single  16240b189369415884b637a5497bbadf
# 49541      F        married  c0268ae7cc4648fb8539c4603bbfddbf
# 49698      F         single  51a6f4039e914d76b33c67382d7e128a
# 49778      F        married  3711a14aa64c419b860fc9eab488834c
# 49790      F         single  90264de4b830421dac7aeebe0a11a2d9
# 49808      F         single  657f374743294aa7a8d5f23e325be42a
# 49862      F         single  933bc18118f84347b6954c64d1815fc6
# 49887      F         single  16240b189369415884b637a5497bbadf
# 49956      F         single  0f275ab72ef1400bb7984a1cebe2dfe5
# 49966      F        married  2ad59ca7a48d4a52ac49940f29f2bd69
#
#                      city   latitude   longitude state zip_code        date
# 7               Los Banos  37.103768 -120.847479    CA    93635  2014-03-01
# 68                Modesto  37.669463 -121.016796    CA    95350  2014-03-01
# 71              Los Banos  37.103768 -120.847479    CA    93635  2014-03-01
# 72              Los Banos  37.103768 -120.847479    CA    93635  2014-03-01
# 90     Desert Hot Springs  33.900103 -116.400701    CA    92240  2014-03-01
# 97            Chula Vista  32.615983 -117.034012    CA    91911  2014-03-01
# 179               Ontario  34.839964 -115.967051    CA    91764  2014-03-01
# 49416              Orange  33.640302 -117.769442    CA    92869  2014-03-31
# 49474            San Jose  37.433587 -121.829615    CA    95132  2014-03-31
# 49541             Oakland  37.761778 -122.198428    CA    94603  2014-03-31
# 49698         North Hills  33.786594 -118.298662    CA    91343  2014-03-31
# 49778         Bakersfield  35.105383 -118.716613    CA    93307  2014-03-31
# 49790              Upland  34.128118 -116.246997    CA    91784  2014-03-31
# 49808            Lakewood  33.840565 -118.078748    CA    90715  2014-03-31
# 49862           Penngrove  38.315342 -122.648346    CA    94951  2014-03-31
# 49887            San Jose  37.433587 -121.829615    CA    95132  2014-03-31
# 49956       San Francisco  37.748932 -122.416281    CA    94110  2014-03-31
# 49966           San Bruno  37.623159 -122.436034    CA    94066  2014-03-31
#
# [1325 rows x 15 columns]

# %% [markdown]
# ### Aggregate
# Groupby the data and create the sum and count of each index. the count can be taken on any columns, here i take gender

# %%
total_amount=f_df.groupby(['age', 'gender','device','date']).agg({'amount' : 'sum','gender':'count'})

# %%
total_amount
# Out:
#                                  amount  gender
# age   gender device  date
# 18-24 F      android 2014-03-01    31.0      13
#                      2014-03-02    69.0       5
#                      2014-03-03    40.0       6
#                      2014-03-04    49.0       7
#                      2014-03-05   113.0       5
#                      2014-03-06     1.0       2
#                      2014-03-07   116.0       8
#                      2014-03-08     0.0       9
#                      2014-03-09    27.0       1
#                      2014-03-10   105.0       9
#                      2014-03-11    45.0       4
#                      2014-03-12   200.0       6
#                      2014-03-13   142.0      11
#                      2014-03-14    85.0       4
#                      2014-03-15   112.0       3
#                      2014-03-16     0.0       3
#                      2014-03-17    57.0       4
#                      2014-03-18    48.0       5
#                      2014-03-19    93.0       5
#                      2014-03-20   177.0       5
#                      2014-03-21    67.0       3
#                      2014-03-22    88.0       7
#                      2014-03-23    57.0       1
#                      2014-03-24   145.0       5
#                      2014-03-25    48.0       2
#                      2014-03-26    76.0       5
#                      2014-03-27     0.0       1
#                      2014-03-28    99.0       4
#                      2014-03-29    54.0       4
#                      2014-03-30   130.0       6
# ...                                 ...     ...
# 55+   F      iOS     2014-03-01     9.0      10
#                      2014-03-02    83.0       7
#                      2014-03-03    29.0       5
#                      2014-03-04     0.0       4
#                      2014-03-05    82.0       6
#                      2014-03-06     0.0       1
#                      2014-03-07     0.0       3
#                      2014-03-08   106.0       5
#                      2014-03-09    32.0       7
#                      2014-03-10    27.0       5
#                      2014-03-11   131.0       2
#                      2014-03-12    58.0       2
#                      2014-03-13     0.0       2
#                      2014-03-14     0.0       3
#                      2014-03-15    83.0       6
#                      2014-03-16    35.0       2
#                      2014-03-17     0.0       3
#                      2014-03-18   112.0       5
#                      2014-03-19    50.0       1
#                      2014-03-20   141.0       5
#                      2014-03-21    40.0       3
#                      2014-03-22     0.0       2
#                      2014-03-23    49.0       2
#                      2014-03-24    29.0       1
#                      2014-03-25   104.0       3
#                      2014-03-26   164.0       5
#                      2014-03-27     0.0       2
#                      2014-03-28    60.0       2
#                      2014-03-29     0.0       2
#                      2014-03-30    86.0       3
#
# [300 rows x 2 columns]

# %% [markdown]
# Rename the amount and count of gender to match the file

# %%
total_amount.rename(index=str, columns={"amount": "sum", "gender": "count"},inplace=True)

# %%
total_amount.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 300 entries, (18-24, F, android, 2014-03-01) to (55+, F, iOS, 2014-03-30)
# Data columns (total 2 columns):
# sum      300 non-null float64
# count    300 non-null int64
# dtypes: float64(1), int64(1)
# memory usage: 6.4+ KB

# %% [markdown]
# reset the index

# %%
total_amount.reset_index(inplace=True)

# %%
total_amount
# Out:
#        age gender   device        date    sum  count
# 0    18-24      F  android  2014-03-01   31.0     13
# 1    18-24      F  android  2014-03-02   69.0      5
# 2    18-24      F  android  2014-03-03   40.0      6
# 3    18-24      F  android  2014-03-04   49.0      7
# 4    18-24      F  android  2014-03-05  113.0      5
# 5    18-24      F  android  2014-03-06    1.0      2
# 6    18-24      F  android  2014-03-07  116.0      8
# 7    18-24      F  android  2014-03-08    0.0      9
# 8    18-24      F  android  2014-03-09   27.0      1
# 9    18-24      F  android  2014-03-10  105.0      9
# 10   18-24      F  android  2014-03-11   45.0      4
# 11   18-24      F  android  2014-03-12  200.0      6
# 12   18-24      F  android  2014-03-13  142.0     11
# 13   18-24      F  android  2014-03-14   85.0      4
# 14   18-24      F  android  2014-03-15  112.0      3
# 15   18-24      F  android  2014-03-16    0.0      3
# 16   18-24      F  android  2014-03-17   57.0      4
# 17   18-24      F  android  2014-03-18   48.0      5
# 18   18-24      F  android  2014-03-19   93.0      5
# 19   18-24      F  android  2014-03-20  177.0      5
# 20   18-24      F  android  2014-03-21   67.0      3
# 21   18-24      F  android  2014-03-22   88.0      7
# 22   18-24      F  android  2014-03-23   57.0      1
# 23   18-24      F  android  2014-03-24  145.0      5
# 24   18-24      F  android  2014-03-25   48.0      2
# 25   18-24      F  android  2014-03-26   76.0      5
# 26   18-24      F  android  2014-03-27    0.0      1
# 27   18-24      F  android  2014-03-28   99.0      4
# 28   18-24      F  android  2014-03-29   54.0      4
# 29   18-24      F  android  2014-03-30  130.0      6
# ..     ...    ...      ...         ...    ...    ...
# 270    55+      F      iOS  2014-03-01    9.0     10
# 271    55+      F      iOS  2014-03-02   83.0      7
# 272    55+      F      iOS  2014-03-03   29.0      5
# 273    55+      F      iOS  2014-03-04    0.0      4
# 274    55+      F      iOS  2014-03-05   82.0      6
# 275    55+      F      iOS  2014-03-06    0.0      1
# 276    55+      F      iOS  2014-03-07    0.0      3
# 277    55+      F      iOS  2014-03-08  106.0      5
# 278    55+      F      iOS  2014-03-09   32.0      7
# 279    55+      F      iOS  2014-03-10   27.0      5
# 280    55+      F      iOS  2014-03-11  131.0      2
# 281    55+      F      iOS  2014-03-12   58.0      2
# 282    55+      F      iOS  2014-03-13    0.0      2
# 283    55+      F      iOS  2014-03-14    0.0      3
# 284    55+      F      iOS  2014-03-15   83.0      6
# 285    55+      F      iOS  2014-03-16   35.0      2
# 286    55+      F      iOS  2014-03-17    0.0      3
# 287    55+      F      iOS  2014-03-18  112.0      5
# 288    55+      F      iOS  2014-03-19   50.0      1
# 289    55+      F      iOS  2014-03-20  141.0      5
# 290    55+      F      iOS  2014-03-21   40.0      3
# 291    55+      F      iOS  2014-03-22    0.0      2
# 292    55+      F      iOS  2014-03-23   49.0      2
# 293    55+      F      iOS  2014-03-24   29.0      1
# 294    55+      F      iOS  2014-03-25  104.0      3
# 295    55+      F      iOS  2014-03-26  164.0      5
# 296    55+      F      iOS  2014-03-27    0.0      2
# 297    55+      F      iOS  2014-03-28   60.0      2
# 298    55+      F      iOS  2014-03-29    0.0      2
# 299    55+      F      iOS  2014-03-30   86.0      3
#
# [300 rows x 6 columns]

# %% [markdown]
# ### Tiny test
# Test a random row see if it is working correctly
#
# 18-24 	F 	android 	2014-03-10 	105.0 	9

# %%
df[(df['age']=='18-24') & (df['device']=='android') &
   (df['date']==datetime.date(2014,3,10)) & (df['state']=='CA') & (df['gender']=='F')].sum()
# Out:
# amount        105.000000
# latitude      315.520548
# longitude   -1066.170009
# dtype: float64

# %%
df[(df['age']=='18-24') & (df['device']=='android') &
   (df['date']==datetime.date(2014,3,10)) & (df['state']=='CA') & (df['gender']=='F')].describe()
# Out:
#           amount   latitude   longitude
# count   9.000000   9.000000    9.000000
# mean   11.666667  35.057839 -118.463334
# std    24.748737   2.089426    2.173986
# min     0.000000  32.775849 -122.124225
# 25%     0.000000  33.640302 -119.592146
# 50%     0.000000  33.786594 -117.769442
# 75%     0.000000  36.832583 -117.207965
# max    70.000000  38.547639 -115.967051

# %% [markdown]
# ### output to csv
# Write the total_amount to a CSV file

# %%
total_amount.to_csv('total_amount.csv')

# %% [markdown]
# ### S3 Upload
# write to s3. First the credential was configured using  AWS CLI  and then the file was uploaded. The code was taken from aws help file.I created the bucket manually could be done also using code. I added the code as the comment

# %%
# Copyright 2010-2019 Amazon.com, Inc. or its affiliates. All Rights Reserved.
#
# This file is licensed under the Apache License, Version 2.0 (the "License").
# You may not use this file except in compliance with the License. A copy of the
# License is located at
#
# http://aws.amazon.com/apache2.0/
#
# This file is distributed on an "AS IS" BASIS, WITHOUT WARRANTIES OR CONDITIONS
# OF ANY KIND, either express or implied. See the License for the specific
# language governing permissions and limitations under the License.





# Create an S3 client
s3 = boto3.client('s3')

filename = 'total_amount.csv'
bucket_name = 'ecosiatest'

# Create bucket 
#s3.create_bucket(Bucket=bucket_name)

# Uploads the given file using a managed uploader, which will split up large
# files automatically and upload parts in parallel.
s3.upload_file(filename, bucket_name, filename)

# %% [markdown]
# ### Download
# To download the total_amount file go to :
#     https://s3.eu-central-1.amazonaws.com/ecosiatest/total_amount.csv

# %% [markdown]
# #### challenges
# - The aws was completely new for me , had to read a bit on it.
# - The aggregation part was kind of fun.
# - Using pandas made everything easy.
# - I first did  part f since it made the aggregation part faster.
# - Stackoverflow and documentations are a gals best friend.
# - Over all the most important thing was that I had fun working on this.
